# %%
import matplotlib.pyplot as plt
import seaborn as sns
df = sns.load_dataset('iris')

# %%
plt.figure(figsize(10,8),dpi=80)
sns.pairplot(df,kind="scatter",hue="species",plot_kws=dict(s=80,edgecolor="white",linewidt=2.5))
plot.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 plt.figure(figsize(10,8),dpi=80)
#       2 sns.pairplot(df,kind="scatter",hue="species",plot_kws=dict(s=80,edgecolor="white",linewidt=2.5))
#       3 plot.show()
#
# NameError: name 'figsize' is not defined
